# %% [markdown]
# # Generating a Cleaned and Useful Expression Matrix
# **Author**: João Guilherme Mendes (joaoguilhermemendes@id.uff.br)
#
# ---
#
# **Data Cleaning and unification of multiple sample files from GEO dataset GSE279208 into a matrix.**
#
# **Goal**: Build a clean transcriptomic expression matrix from the individual RNA-seq sample files.
#
# ---
#
# ### Imports

# %%
from pathlib import Path
import pandas as pd

from src.preprocessing.check_gene_consistency import (
    check_gene_consistency
)

from src.preprocessing.load_metadata import (
    load_metadata
)

# %% [markdown]
# ---
#
# ### Create interim folder, Clean and Save

# %%
from pathlib import Path

interim_dir = Path("../data/interim")

interim_dir.mkdir(
    parents=True,
    exist_ok=True
)

files = sorted(
    Path("../data/raw").glob("*.xls")
)

for file in files:

    df = pd.read_csv(file, sep="\t")

    # Remove non-coding genes
    df = df[df["Type"] == "mRNA"]

    # Build output path
    output_path = interim_dir / file.name

    # Save cleaned file
    df.to_csv(
        output_path,
        sep="\t",
        index=False
    )

    print(f"Saved: {file.name}")
# Out:
# Saved: GSM8564259_HCB1-21.xls
# Saved: GSM8564260_HCB2-21.xls
# Saved: GSM8564261_HCB3-21.xls
# Saved: GSM8564262_HCB5-21.xls
# Saved: GSM8564263_HCB6-21.xls
# Saved: GSM8564264_HCB7-21.xls
# Saved: GSM8564265_HCB8-21.xls
# Saved: GSM8564266_HCB9-21.xls
# Saved: GSM8564267_HCB10-21.xls
# Saved: GSM8564268_HCB11-21.xls
# Saved: GSM8564269_PTB1-21.xls
# Saved: GSM8564270_PTB1-22.xls
# Saved: GSM8564271_PTB2-21.xls
# Saved: GSM8564272_PTB2-22.xls
# Saved: GSM8564273_PTB3-21.xls
# Saved: GSM8564274_PTB3-22.xls
# Saved: GSM8564275_PTB4-21.xls
# Saved: GSM8564276_PTB5-21.xls
# Saved: GSM8564277_PTB6-21.xls
# Saved: GSM8564278_PTB7-21.xls
# Saved: GSM8564279_PTB8-21.xls
# Saved: GSM8564280_PTB9-21.xls
# Saved: GSM8564281_PTB10-21.xls
# Saved: GSM8564282_PTB11-21.xls
# Saved: GSM8564283_PTB12-21.xls
# Saved: GSM8564284_PTB13-21.xls

# %% [markdown]
# ---
#
# ### Load all the files
#
# At the moment, all the sample files are separeted from each other. Must be executed a verification to check if the file structure are stricly the same in every file, and then unify to further analysis.

# %%
files = list(Path("../data/raw").glob("*.xls"))

for file in files:
    print(file)
# Out:
# ..\data\raw\GSM8564259_HCB1-21.xls
# ..\data\raw\GSM8564260_HCB2-21.xls
# ..\data\raw\GSM8564261_HCB3-21.xls
# ..\data\raw\GSM8564262_HCB5-21.xls
# ..\data\raw\GSM8564263_HCB6-21.xls
# ..\data\raw\GSM8564264_HCB7-21.xls
# ..\data\raw\GSM8564265_HCB8-21.xls
# ..\data\raw\GSM8564266_HCB9-21.xls
# ..\data\raw\GSM8564267_HCB10-21.xls
# ..\data\raw\GSM8564268_HCB11-21.xls
# ..\data\raw\GSM8564269_PTB1-21.xls
# ..\data\raw\GSM8564270_PTB1-22.xls
# ..\data\raw\GSM8564271_PTB2-21.xls
# ..\data\raw\GSM8564272_PTB2-22.xls
# ..\data\raw\GSM8564273_PTB3-21.xls
# ..\data\raw\GSM8564274_PTB3-22.xls
# ..\data\raw\GSM8564275_PTB4-21.xls
# ..\data\raw\GSM8564276_PTB5-21.xls
# ..\data\raw\GSM8564277_PTB6-21.xls
# ..\data\raw\GSM8564278_PTB7-21.xls
# ..\data\raw\GSM8564279_PTB8-21.xls
# ..\data\raw\GSM8564280_PTB9-21.xls
# ..\data\raw\GSM8564281_PTB10-21.xls
# ..\data\raw\GSM8564282_PTB11-21.xls
# ..\data\raw\GSM8564283_PTB12-21.xls
# ..\data\raw\GSM8564284_PTB13-21.xls

# %% [markdown]
# ---
#
# ### Check the columns consistency accros the files

# %%
files = sorted(
    Path("../data/interim").glob("*.xls")
)

all_consistent = check_gene_consistency(files)

print(f"All files consistent: {all_consistent}")
# Out:
# Reference file: GSM8564259_HCB1-21.xls
# Total genes: 16484
#
# GSM8564260_HCB2-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564261_HCB3-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564262_HCB5-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564263_HCB6-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564264_HCB7-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564265_HCB8-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564266_HCB9-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564267_HCB10-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564268_HCB11-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564269_PTB1-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564270_PTB1-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564271_PTB2-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564272_PTB2-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564273_PTB3-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564274_PTB3-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564275_PTB4-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564276_PTB5-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564277_PTB6-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564278_PTB7-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564279_PTB8-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564280_PTB9-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564281_PTB10-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564282_PTB11-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564283_PTB12-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564284_PTB13-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# All files consistent: True

# %% [markdown]
# By this looop, was identified inconsistenses in the columns order from the sample HCB10 and HCB11.

# %%
import pandas as pd

wrong_files = [
    "../data/raw/GSM8564267_HCB10-21.xls",
    "../data/raw/GSM8564268_HCB11-21.xls"
]

for file in wrong_files:

    file_df = pd.read_csv(file, sep="\t")

    # Get columns
    cols = list(file_df.columns)

    # Swap columns 'Transcription ID' and 'HCB10-21 FPKM/HCB11-21 FPKM'
    cols[3], cols[5] = cols[5], cols[3]

    # Reorder dataframe
    file_df = file_df[cols]

    # Print new order
    print(f"\n{file}")
    print(file_df.columns[0]+" | "+
          file_df.columns[1]+" | "+
          file_df.columns[2]+" | "+
          file_df.columns[3]+" | "+
          file_df.columns[4]+" | "+
          file_df.columns[5]+" | "+
          file_df.columns[6])

    # overwrite file
    file_df.to_csv(file, sep="\t", index=False)
# Out:
# ../data/raw/GSM8564267_HCB10-21.xls
# Gene ID | Gene Symbol | Type | Transcripts ID | HCB10-21 Read Count | HCB10-21 FPKM | HCB10-21 TPM
#
# ../data/raw/GSM8564268_HCB11-21.xls
# Gene ID | Gene Symbol | Type | Transcripts ID | HCB11-21 Read Count | HCB11-21 FPKM | HCB11-21 TPM

# %% [markdown]
# ---
#
# ### Checking if all of them have the same genes in the same order

# %%
from pathlib import Path
import pandas as pd

# Load reference file
reference_df = pd.read_csv(files[0], sep="\t")

# Use Gene ID as reference
reference_genes = reference_df["Gene ID"].tolist()

print(f"Reference file: {files[0].name}")
print(f"Total genes: {len(reference_genes)}\n")

# Compare all files
for file in files[1:]:

    df = pd.read_csv(file, sep="\t")

    current_genes = df["Gene ID"].tolist()

    same_gene_count = len(reference_genes) == len(current_genes)
    same_gene_set = set(reference_genes) == set(current_genes)
    same_gene_order = reference_genes == current_genes

    print(f"{file.name}")
    print(f"Same gene count: {same_gene_count}")
    print(f"Same gene set: {same_gene_set}")
    print(f"Same gene order: {same_gene_order}\n")
# Out:
# Reference file: GSM8564259_HCB1-21.xls
# Total genes: 16484
#
# GSM8564260_HCB2-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564261_HCB3-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564262_HCB5-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564263_HCB6-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564264_HCB7-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564265_HCB8-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564266_HCB9-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564267_HCB10-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564268_HCB11-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564269_PTB1-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564270_PTB1-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564271_PTB2-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564272_PTB2-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564273_PTB3-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564274_PTB3-22.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564275_PTB4-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564276_PTB5-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564277_PTB6-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564278_PTB7-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564279_PTB8-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564280_PTB9-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564281_PTB10-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564282_PTB11-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564283_PTB12-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True
#
# GSM8564284_PTB13-21.xls
# Same gene count: True
# Same gene set: True
# Same gene order: True

# %% [markdown]
# ---
#
# ### Checking if that's any duplicated genes

# %%
duplicates = 0
missing_values = 0

for file in files:

    file_df = pd.read_csv(file, sep='\t')

    if (
        file_df["Gene ID"].duplicated().sum() > 0
        or file_df["Gene Symbol"].duplicated().sum() > 0
    ):
        duplicates += 1

    if file_df.isna().sum().sum() > 0:
        missing_values += 1

print("Duplicated 'Gene ID' or 'Gene Symbol':", duplicates)
print("Files with missing values:", missing_values)
# Out:
# Duplicated 'Gene ID' or 'Gene Symbol': 0
# Files with missing values: 0

# %% [markdown]
# ---
#
# ### Filtering Non-Coding Genes
#
# The original RNA-seq files contain multiple transcript types, including non-coding RNAs, pseudogenes, and other non-protein-coding features.
#
# Since the main objective of this project is to investigate biologically interpretable gene expression patterns associated with dengue severity, only genes classified as `"mRNA"` were retained.
#
# This filtering step reduces noise and focuses the analysis on protein-coding genes, which are typically more suitable for downstream differential expression and pathway analysis.

# %%
for file in files:
    file_df = pd.read_csv(file, sep="\t")
    file_df = file_df[file_df["Type"] == "mRNA"]

    output_path = Path("../data/interim") / file.name
    file_df.to_csv(output_path, sep="\t", index=False)

# %%
files = sorted(
    Path("../data/raw").glob("*.xls")
)

total_removed = 0

for file in files:

    file_df = pd.read_csv(file, sep="\t")

    original_rows = len(file_df)

    # Keep only protein-coding genes
    file_df = file_df[file_df["Type"] == "mRNA"]

    filtered_rows = len(file_df)
    removed_rows = original_rows - filtered_rows
    total_removed += removed_rows

    output_path = Path("../data/interim") / file.name

    file_df.to_csv(
        output_path,
        sep="\t",
        index=False
    )

    print(
        f"{file.name}: "
        f"removed {removed_rows} non-coding entries"
    )

print("\nTotal removed entries:", total_removed)
# Out:
# GSM8564259_HCB1-21.xls: removed 158 non-coding entries
# GSM8564260_HCB2-21.xls: removed 158 non-coding entries
# GSM8564261_HCB3-21.xls: removed 158 non-coding entries
# GSM8564262_HCB5-21.xls: removed 158 non-coding entries
# GSM8564263_HCB6-21.xls: removed 158 non-coding entries
# GSM8564264_HCB7-21.xls: removed 158 non-coding entries
# GSM8564265_HCB8-21.xls: removed 158 non-coding entries
# GSM8564266_HCB9-21.xls: removed 158 non-coding entries
# GSM8564267_HCB10-21.xls: removed 158 non-coding entries
# GSM8564268_HCB11-21.xls: removed 158 non-coding entries
# GSM8564269_PTB1-21.xls: removed 158 non-coding entries
# GSM8564270_PTB1-22.xls: removed 158 non-coding entries
# GSM8564271_PTB2-21.xls: removed 158 non-coding entries
# GSM8564272_PTB2-22.xls: removed 158 non-coding entries
# GSM8564273_PTB3-21.xls: removed 158 non-coding entries
# GSM8564274_PTB3-22.xls: removed 158 non-coding entries
# GSM8564275_PTB4-21.xls: removed 158 non-coding entries
# GSM8564276_PTB5-21.xls: removed 158 non-coding entries
# GSM8564277_PTB6-21.xls: removed 158 non-coding entries
# GSM8564278_PTB7-21.xls: removed 158 non-coding entries
# GSM8564279_PTB8-21.xls: removed 158 non-coding entries
# GSM8564280_PTB9-21.xls: removed 158 non-coding entries
# GSM8564281_PTB10-21.xls: removed 158 non-coding entries
# GSM8564282_PTB11-21.xls: removed 158 non-coding entries
# GSM8564283_PTB12-21.xls: removed 158 non-coding entries
# GSM8564284_PTB13-21.xls: removed 158 non-coding entries
#
# Total removed entries: 4108

# %% [markdown]
# ---

# %% [markdown]
# ## Build the TPM Matrix

# %%
from pathlib import Path
import pandas as pd

# Get all files
files = sorted(Path("../data/raw").glob("*.xls"))

# Load first file as base
base_df = pd.read_csv(files[0], sep="\t")

# Keep annotation columns
expression_matrix = base_df[["Gene ID", "Gene Symbol"]].copy()

# Add TPM columns
for file in files:
    df = pd.read_csv(file, sep="\t")

    # Find TPM column automatically
    tpm_col = [col for col in df.columns if "TPM" in col][0]

    # Extract sample name
    sample_name = tpm_col.replace(" TPM", "")

    # Add TPM values to matrix
    expression_matrix[sample_name] = df[tpm_col]

    print(f"Added: {sample_name}")

# Save matrix
expression_matrix.to_csv(
    "../data/processed/expression_matrix_tpm.csv",
    index=False
)

print("\nTPM expression matrix saved successfully!")
# Out:
# Added: HCB1-21
# Added: HCB2-21
# Added: HCB3-21
# Added: HCB5-21
# Added: HCB6-21
# Added: HCB7-21
# Added: HCB8-21
# Added: HCB9-21
# Added: HCB10-21
# Added: HCB11-21
# Added: PTB1-21
# Added: PTB1-22
# Added: PTB2-21
# Added: PTB2-22
# Added: PTB3-21
# Added: PTB3-22
# Added: PTB4-21
# Added: PTB5-21
# Added: PTB6-21
# Added: PTB7-21
# Added: PTB8-21
# Added: PTB9-21
# Added: PTB10-21
# Added: PTB11-21
# Added: PTB12-21
# Added: PTB13-21
#
# TPM expression matrix saved successfully!

# %%
expression_matrix.head(10)
# Out:
#      Gene ID Gene Symbol  HCB1-21  HCB2-21  HCB3-21  HCB5-21  HCB6-21  \
# 0          1      'A1BG'     2.52     2.69     3.88     1.79     3.74
# 1        100       'ADA'    32.87    12.30    28.91    29.54    24.33
# 2       1000      'CDH2'     0.46     0.44     0.29     0.00     0.06
# 3      10000      'AKT3'     9.29     4.55     6.04     6.93     5.60
# 4      10001      'MED6'    15.79     5.62     6.62     6.49     6.23
# 5      10003   'NAALAD2'     0.45     0.33     0.72     0.48     0.53
# 6  100037417      'DDTL'     2.06     2.23     3.00     1.85     2.01
# 7      10004  'NAALADL1'     5.22     3.51     4.76     4.85     7.75
# 8  100049587  'SIGLEC14'    89.79    71.22   104.82    61.65     0.00
# 9      10005     'ACOT8'    25.79    24.26    30.70    32.76    31.63
#
#    HCB7-21  HCB8-21  HCB9-21  ...  PTB4-21  PTB5-21  PTB6-21  PTB7-21  \
# 0     2.97     3.23     3.42  ...     2.53     1.03     2.44     1.85
# 1    24.13    30.08    39.23  ...    77.21   104.87    48.45    71.44
# 2     0.11     0.18     0.00  ...     0.15     0.32     0.00     0.07
# 3     6.71    12.89    11.33  ...     3.59     9.39    10.33     5.25
# 4     7.23    15.57    13.85  ...    23.34    28.95    14.52    22.50
# 5     0.80     0.75     1.05  ...     0.19     0.27     0.66     0.17
# 6     2.16     3.29     5.91  ...     5.37     2.89     3.56     2.01
# 7     7.05     5.79     7.25  ...     2.98     1.83     5.89     2.10
# 8    18.25     0.03    33.17  ...     0.15     0.00   205.38    18.35
# 9    30.43    24.74    26.23  ...    35.30    33.21    35.99    28.82
#
#    PTB8-21  PTB9-21  PTB10-21  PTB11-21  PTB12-21  PTB13-21
# 0     2.38     1.69      1.61      1.19      2.13      1.75
# 1    38.44    75.32      9.81     93.56     26.21     46.43
# 2     0.00     0.10      0.06      0.05      0.00      0.00
# 3     9.62     4.14      1.81      6.46      3.25      2.30
# 4    18.80    12.55      3.34     18.94      7.43      7.18
# 5     0.55     0.16      0.23      0.18      0.59      0.52
# 6     3.67     2.49      1.97      2.33      2.57      4.28
# 7     4.55     4.81      1.89      2.97      2.84      3.42
# 8     0.00     0.00      0.00     17.80      0.00    311.60
# 9    33.61    33.77     19.37     21.47     21.54     21.04
#
# [10 rows x 28 columns]

# %% [markdown]
# ---
#
# ## Final Considerations
#
# In this notebook, the raw RNA-seq files downloaded from GEO were transformed into a clean and structured TPM expression matrix ready for downstream transcriptomic analysis.
#
# The original dataset consisted of separate RNA-seq sample files containing mixed transcript annotations and multiple expression metrics. After preprocessing, the data was reorganized into a single, clean TPM expression matrix, where each column represents a sample and each row represents a gene.
#
# This processed dataset is now ready for exploratory visualization, dimensionality reduction, clustering, and further transcriptomic analysis.

# %% [markdown]
# ---
#
# ### Next Step...
#
# In `03_Visualizing_Data.ipynb`, the cleaned TPM expression matrix will be explored through visualizations and exploratory analyses such as PCA and clustering.
#
# Because TPM values are highly skewed, log-transformation will likely be applied before downstream analysis.
